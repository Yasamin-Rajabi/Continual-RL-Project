# %%
import os

if not os.path.exists('/kaggle/working/Continual-RL-Project'):
    # !git clone https://github.com/Yasamin-Rajabi/Continual-RL-Project.git

# %cd /kaggle/working/Continual-RL-Project

# !git fetch origin
# !git checkout Narges
# !git pull origin Narges

# !pip install "mujoco>=3.0.0"
# !pip install --no-deps git+https://github.com/Farama-Foundation/Metaworld.git@c822f28f582ba1ad49eb5dcf61016566f28003ba
# !grep -v -E "metaworld|mujoco" requirements.txt > reqs_clean.txt
# !pip install -q -r reqs_clean.txt

# !python run_experiments.py --algorithm cka-rl --fusion-mode classic_cka --seed 42 --tag Baseline_Run --pool_size 2
# !python run_experiments.py --algorithm cka-rl --fusion-mode weight_delta --seed 42 --tag Ours_WeightDelta --pool_size 2
# Out:
# Cloning into 'Continual-RL-Project'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 64 (delta 28), reused 53 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 61.56 KiB | 2.28 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /kaggle/working/Continual-RL-Project
# Branch 'Narges' set up to track remote branch 'Narges' from 'origin'.
# Switched to a new branch 'Narges'
# From https://github.com/Yasamin-Rajabi/Continual-RL-Project
#  * branch            Narges     -> FETCH_HEAD
# Already up to date.
# Collecting mujoco>=3.0.0
#   Downloading mujoco-3.11.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.0.0) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.0.0) (1.14.0)
# Collecting glfw (from mujoco>=3.0.0)
#   Downloading glfw-2.10.2-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.0.0) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.0.0) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.0.0) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.0.0) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.0.0) (3.23.1)
# Downloading mujoco-3.11.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 77.3 MB/s eta 0:00:00
# Downloading glfw-2.10.2-py2.py3-none-manylinux_2_28_x86_64.whl (248 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.10.2 mujoco-3.11.0
# Collecting git+https://github.com/Farama-Foundation/Metaworld.git@c822f28f582ba1ad49eb5dcf61016566f28003ba
#   Cloning https://github.com/Farama-Foundation/Metaworld.git (to revision c822f28f582ba1ad49eb5dcf61016566f28003ba) to /tmp/pip-req-build-6ece0igy
#   Running command git clone --filter=blob:none --quiet https://github.com/Farama-Foundation/Metaworld.git /tmp/pip-req-build-6ece0igy
#   Running command git rev-parse -q --verify 'sha^c822f28f582ba1ad49eb5dcf61016566f28003ba'
#   Running command git fetch -q https://github.com/Farama-Foundation/Metaworld.git c822f28f582ba1ad49eb5dcf61016566f28003ba
#   Running command git checkout -q c822f28f582ba1ad49eb5dcf61016566f28003ba
#   Resolved https://github.com/Farama-Foundation/Metaworld.git to commit c822f28f582ba1ad49eb5dcf61016566f28003ba
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: metaworld
#   Building wheel for metaworld (pyproject.toml) ... done
#   Created wheel for metaworld: filename=metaworld-2.0.0-py3-none-any.whl size=84323717 sha256=4a5a63410e9094747f1a5aaa05d6adf41f8039b36866a74b57f8b1f15c94c374
#   Stored in directory: /root/.cache/pip/wheels/fa/b2/fc/d531d4f97fcfbf4f961b9de6505a497888828f42e6ba2146c0
# Successfully built metaworld
# Installing collected packages: metaworld
# Successfully installed metaworld-2.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
# python3 run_sac.py --model-type=cka-rl --task-id=1 --seed=42 --tag=Baseline_Run --fusion-mode=classic_cka --no-encoder-from-base --save-dir=agents/Baseline_Run --pool_size=2
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/tyro/_parsers.py:352: UserWarning: The field `wandb-entity` is annotated with type `<class 'str'>`, but the default value `None` has type `<class 'NoneType'>`. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(message)
#
# *** Run name: task_1__cka-rl__run_sac__42 ***
#
# *** Device: cuda
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# 39
# 4
# *** Loading model `cka-rl` ***
# 2026-07-30 20:10:38.786 | INFO     | cka_rl:log_alpha:258 - None
# 2026-07-30 20:10:38.786 | INFO     | cka_rl:__init__:71 - Train shared from scratch
# 2026-07-30 20:10:38.802 | DEBUG    | cka_rl:setup_heads:78 - CKA-RL fuse heads
# 100%|██████████████████████████████████████████| 50/50 [00:00<00:00, 511.92it/s]
# *** Generating online comprehensive distillation buffer for 10000 steps ***
#
# TEST: ep_ret=1296.6698548827449, success=0.0
#
# Saving trained agent in `agents/Baseline_Run` with name `task_1__cka-rl__run_sac__42`
# 2026-07-30 20:11:37.949 | INFO     | cka_rl:save:151 - save weight as theta
# 2026-07-30 20:11:37.949 | INFO     | cka_rl:save:154 - Saving 2-layer high-capacity Sequential policy heads...
# python3 run_sac.py --model-type=cka-rl --task-id=3 --seed=42 --tag=Baseline_Run --fusion-mode=classic_cka --no-encoder-from-base --save-dir=agents/Baseline_Run --pool_size=2 --prev-units agents/Baseline_Run/task_1__cka-rl__run_sac__42
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/tyro/_parsers.py:352: UserWarning: The field `wandb-entity` is annotated with type `<class 'str'>`, but the default value `None` has type `<class 'NoneType'>`. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(message)
#
# *** Run name: task_3__cka-rl__run_sac__42 ***
#
# *** Device: cuda
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# 39
# 4
# *** Loading model `cka-rl` ***
# 2026-07-30 20:11:48.716 | DEBUG    | cka_rl:setup_vectors:184 - Setup head's vectors
# Traceback (most recent call last):
#   File "/kaggle/working/Continual-RL-Project/run_sac.py", line 302, in <module>
#     model = CkaRlAgent(
#             ^^^^^^^^^^^
#   File "/kaggle/working/Continual-RL-Project/cka_rl.py", line 55, in __init__
#     self.setup_vectors(base_dir, latest_dir)
#   File "/kaggle/working/Continual-RL-Project/cka_rl.py", line 226, in setup_vectors
#     logger.debug(self.fc_mean_vectors['weight'].shape)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1965, in __getattr__
#     raise AttributeError(
# AttributeError: 'CkaRlAgent' object has no attribute 'fc_mean_vectors'
# *** Process returned code 1. Stopping on error.
# python3 run_sac.py --model-type=cka-rl --task-id=1 --seed=42 --tag=Ours_WeightDelta --fusion-mode=weight_delta --no-encoder-from-base --save-dir=agents/Ours_WeightDelta --pool_size=2
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/tyro/_parsers.py:352: UserWarning: The field `wandb-entity` is annotated with type `<class 'str'>`, but the default value `None` has type `<class 'NoneType'>`. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(message)
#
# *** Run name: task_1__cka-rl__run_sac__42 ***
#
# *** Device: cuda
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# 39
# 4
# *** Loading model `cka-rl` ***
# 2026-07-30 20:11:58.157 | INFO     | cka_rl:log_alpha:258 - None
# 2026-07-30 20:11:58.157 | INFO     | cka_rl:__init__:71 - Train shared from scratch
# 2026-07-30 20:11:58.159 | DEBUG    | cka_rl:setup_heads:78 - CKA-RL fuse heads
# 100%|██████████████████████████████████████████| 50/50 [00:00<00:00, 410.45it/s]
# *** Generating online comprehensive distillation buffer for 10000 steps ***
#
# TEST: ep_ret=1296.6698548827449, success=0.0
#
# Saving trained agent in `agents/Ours_WeightDelta` with name `task_1__cka-rl__run_sac__42`
# 2026-07-30 20:12:54.491 | INFO     | cka_rl:save:151 - save weight as theta
# 2026-07-30 20:12:54.492 | INFO     | cka_rl:save:154 - Saving 2-layer high-capacity Sequential policy heads...
# python3 run_sac.py --model-type=cka-rl --task-id=3 --seed=42 --tag=Ours_WeightDelta --fusion-mode=weight_delta --no-encoder-from-base --save-dir=agents/Ours_WeightDelta --pool_size=2 --prev-units agents/Ours_WeightDelta/task_1__cka-rl__run_sac__42
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/tyro/_parsers.py:352: UserWarning: The field `wandb-entity` is annotated with type `<class 'str'>`, but the default value `None` has type `<class 'NoneType'>`. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(message)
#
# *** Run name: task_3__cka-rl__run_sac__42 ***
#
# *** Device: cuda
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# 39
# 4
# *** Loading model `cka-rl` ***
# 2026-07-30 20:13:03.695 | DEBUG    | cka_rl:setup_vectors:184 - Setup head's vectors
# Traceback (most recent call last):
#   File "/kaggle/working/Continual-RL-Project/run_sac.py", line 302, in <module>
#     model = CkaRlAgent(
#             ^^^^^^^^^^^
#   File "/kaggle/working/Continual-RL-Project/cka_rl.py", line 55, in __init__
#     self.setup_vectors(base_dir, latest_dir)
#   File "/kaggle/working/Continual-RL-Project/cka_rl.py", line 226, in setup_vectors
#     logger.debug(self.fc_mean_vectors['weight'].shape)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1965, in __getattr__
#     raise AttributeError(
# AttributeError: 'CkaRlAgent' object has no attribute 'fc_mean_vectors'
# *** Process returned code 1. Stopping on error.
